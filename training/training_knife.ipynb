# %%
import cv2
from darkflow.net.build import TFNet
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### 1e-4 : 15
# ### 1e-5 : 60
# ### 1e-6 : -

# %%
options = {"model": "cfg/yolo-voc-test-knife.cfg", 
           "batch": 4,
           "epoch": 60,
           "load" : -1,
           "gpu": 0.5,
           "lr" : 1e-5,
           "train": True,
           "trainer" : "adam",
           "annotation": "./data/annotations_knife/",
           "dataset": "./data/dataset_knife/"}


tfnet = TFNet(options)
# Out:
# Parsing cfg/yolo-voc-test-knife.cfg
# Loading None ...
# Finished in 0.0s
#
# Building net ...
# Source | Train? | Layer description                | Output size
# -------+--------+----------------------------------+---------------
#        |        | input                            | (?, 416, 416, 3)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 416, 416, 32)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 208, 208, 32)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 208, 208, 64)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 104, 104, 64)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 104, 104, 128)
#  Init  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 104, 104, 64)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 104, 104, 128)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 52, 52, 128)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 52, 52, 256)
# ...

# %%
tfnet.train()
# Out:
# cfg/yolo-voc-test-knife.cfg parsing ./data/annotations_knife/
# Parsing for ['knife']
# [====================>]100%  vertical_knife_20200921_99.xml
# Statistics:
# knife: 2631
# Dataset size: 2396
# Dataset of 2396 instance(s)
# Training statistics:
# 	Learning rate : 1e-05
# 	Batch size    : 4
# 	Epoch number  : 60
# 	Backup every  : 2000
# step 8986 - loss 2.1607868671417236 - moving ave loss 2.1607868671417236
# step 8987 - loss 2.515699625015259 - moving ave loss 2.196278142929077
# step 8988 - loss 2.4054174423217773 - moving ave loss 2.217192072868347
# step 8989 - loss 1.21492600440979 - moving ave loss 2.1169654660224917
# step 8990 - loss 1.609053134918213 - moving ave loss 2.066174232912064
# step 8991 - loss 2.1124515533447266 - moving ave loss 2.07080196495533
# step 8992 - loss 0.6517072916030884 - moving ave loss 1.928892497620106
# step 8993 - loss 2.4181289672851562 - moving ave loss 1.9778161445866111
# ...

# %% [markdown]
# ## 테스트용 options

# %%
options = {
    'model' : "cfg/yolo-voc-test-knife.cfg",
    'load' : -1,
    'threshold' : 0.4,
    'gpu' : 0.5
}

tfnet = TFNet(options)
# Out:
# Parsing cfg/yolo-voc-test-knife.cfg
# Loading None ...
# Finished in 0.0s
#
# Building net ...
# Source | Train? | Layer description                | Output size
# -------+--------+----------------------------------+---------------
#        |        | input                            | (?, 416, 416, 3)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 416, 416, 32)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 208, 208, 32)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 208, 208, 64)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 104, 104, 64)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 104, 104, 128)
#  Init  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 104, 104, 64)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 104, 104, 128)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 52, 52, 128)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 52, 52, 256)
# ...

# %% [markdown]
# ## 영상 테스트

# %%
cap = cv2.VideoCapture('knife_test_final.mp4')

width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# 비디오 코덱은 XVID
fourcc = cv2.VideoWriter_fourcc(*'XVID')
# 30프레임짜리 XVID코덱으로 저장하는 포맷 변수 선언
writer = cv2.VideoWriter('output_knife_final_6.avi', fourcc, 30.0, (width, height))
while(cap.isOpened()) :
    ret, frame = cap.read()
    if ret == False:
        break
    result = tfnet.return_predict(frame)
    result_img = frame.copy()
    # 모자이크 처리 부분
    if result:
        print(result)
        for res in result:
            x = res['topleft']['x']
            y = res['topleft']['y']
            w = res['bottomright']['x']
            h = res['bottomright']['y']
            target = frame[y:h, x:w]
            flt = cv2.blur(target, (90, 90))  # blur처리 한 후 flt 변수에 저장
            result_img[y:h, x:w] = flt
            tl = (x, y)
            br = (w ,h)
            label = res['label']
            conf = res['confidence']
            result_img= cv2.rectangle(result_img, tl, br, (0, 255, 0), 2)
            #result_img= cv2.putText(result_img, label, tl, cv2.FONT_HERSHEY_TRIPLEX, 1, (0,0,0), 2)
        
    else :
        result_img = frame.copy()
        

    writer.write(result_img)

    if cv2.waitKey(1)&0xFF == 27:
        break
cv2.destroyAllWindows()
# Out:
# [{'label': 'knife', 'confidence': 0.45984674, 'topleft': {'x': 0, 'y': 416}, 'bottomright': {'x': 1376, 'y': 598}}]
# [{'label': 'knife', 'confidence': 0.46475443, 'topleft': {'x': 0, 'y': 416}, 'bottomright': {'x': 1374, 'y': 598}}]
# [{'label': 'knife', 'confidence': 0.48375124, 'topleft': {'x': 0, 'y': 416}, 'bottomright': {'x': 1376, 'y': 598}}]
# [{'label': 'knife', 'confidence': 0.46336356, 'topleft': {'x': 0, 'y': 416}, 'bottomright': {'x': 1375, 'y': 597}}]
# [{'label': 'knife', 'confidence': 0.45861462, 'topleft': {'x': 0, 'y': 416}, 'bottomright': {'x': 1371, 'y': 598}}]
# [{'label': 'knife', 'confidence': 0.4136048, 'topleft': {'x': 0, 'y': 412}, 'bottomright': {'x': 1348, 'y': 564}}]
# [{'label': 'knife', 'confidence': 0.4768938, 'topleft': {'x': 0, 'y': 412}, 'bottomright': {'x': 1354, 'y': 563}}]
# [{'label': 'knife', 'confidence': 0.48095047, 'topleft': {'x': 0, 'y': 412}, 'bottomright': {'x': 1356, 'y': 564}}]
# ...

# %% [markdown]
# ## 사진 테스트

# %%
test = cv2.imread("knife1.jpg")
colors=[tuple(255 * np.random.rand(3)) for i in range(5)]

result = tfnet.return_predict(test)

t1 = (result[0]['topleft']['x'], result[0]['topleft']['y'])
br = (result[0]['bottomright']['x'], result[0]['bottomright']['y'])
label = result[0]['label']

test = cv2.rectangle(test, t1, br, (0, 255, 0), 7)

test = cv2.putText(test, label, t1, cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,0), 2)
cv2.imshow('frame', test)
if cv2.waitKey(1)&0xFF == 27:
    cv2.destroyAllWindows()
